# %% [markdown]
# # Problema
#
# Esta semana utilizaremos el mismo DataSet para ambas sesiones. Ésta primera sesión será para analizar un problema de fraude de modo sencillo, es decir, con un clasificador binario sencillo (que nos servirá para introducir algunas herramientas).
#
# Podemos encontrar la base de datos en https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
#
# Los datos contienen transacciones realizadas mediante trarjeta de crédito en Septiembre del 2013 por titulares de tarjeta en Europa. Ocurrieron en 2 días en los que hubo 492 fraudes de 284,807 transacciones.
#
# Solo contiene variables numéricas y ya pasó por un proceso de PCA para solo quedarse con las mejores características.
#
# La columna de "Time" contiene los segundos ocurridos entre transacciones."Amount" es la cantidad de la transacción y "Class" es la variable que tiene 1 en caso de fraude y 0 en caso contrario.
#
#
#
# Given the class imbalance ratio, we recommend measuring the accuracy using the Area Under the Precision-Recall Curve (AUPRC). Confusion matrix accuracy is not meaningful for unbalanced classification.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Cruso-ApsFinancieras/semana3/'

# %% [markdown]
# # Leer Datos usando un método distinto al que estamos acostumbrados

# %%
import numpy as np

# Get the real data from https://www.kaggle.com/mlg-ulb/creditcardfraud/
fname = "creditcard.csv"

all_features = []
all_targets = []
with open(path + fname) as f:
    for i, line in enumerate(f):
        if i == 0:
            print("HEADER:", line.strip())
            continue  # Skip header
        fields = line.strip().split(",")
        all_features.append([float(v.replace('"', "")) for v in fields[:-1]])
        all_targets.append([int(fields[-1].replace('"', ""))])
        if i == 1:
            print("EXAMPLE FEATURES:", all_features[-1])

features = np.array(all_features, dtype="float32")
targets = np.array(all_targets, dtype="uint8")
print("features.shape:", features.shape)
print("targets.shape:", targets.shape)
# Out:
# HEADER: "Time","V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V11","V12","V13","V14","V15","V16","V17","V18","V19","V20","V21","V22","V23","V24","V25","V26","V27","V28","Amount","Class"
# EXAMPLE FEATURES: [0.0, -1.3598071336738, -0.0727811733098497, 2.53634673796914, 1.37815522427443, -0.338320769942518, 0.462387777762292, 0.239598554061257, 0.0986979012610507, 0.363786969611213, 0.0907941719789316, -0.551599533260813, -0.617800855762348, -0.991389847235408, -0.311169353699879, 1.46817697209427, -0.470400525259478, 0.207971241929242, 0.0257905801985591, 0.403992960255733, 0.251412098239705, -0.018306777944153, 0.277837575558899, -0.110473910188767, 0.0669280749146731, 0.128539358273528, -0.189114843888824, 0.133558376740387, -0.0210530534538215, 149.62]
# features.shape: (284807, 30)
# targets.shape: (284807, 1)

# %% [markdown]
# # Preparar conjunto de validación
#
# Lo haremos manual (es decir, no aleatorio)

# %%
num_val_samples = int(len(features) * 0.2)
train_features = features[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_features = features[-num_val_samples:]
val_targets = targets[-num_val_samples:]

print("Number of training samples:", len(train_features))
print("Number of validation samples:", len(val_features))
# Out:
# Number of training samples: 227846
# Number of validation samples: 56961

# %% [markdown]
# # Analizar desbalance de los datos

# %%
counts = np.bincount(train_targets[:, 0])
print(f"Number of positive samples in training data: {counts[1]} ({100 * float(counts[1]) / len(train_targets):.2f}% of total)")
# Out:
# Number of positive samples in training data: 417 (0.18% of total)

# %% [markdown]
# Asignaremos pesos de una manera balanceada (es una clase de peso "balanced" utilizada en keras). Manualmente se calcula como:

# %%
total_counts = np.bincount(train_targets[:, 0])
n_samples = len(train_targets)

weight_for_0 = n_samples / (total_counts[0]*2)
weight_for_1 = n_samples / (total_counts[1]*2)

#counts = np.bincount(train_targets[:, 0])

#weight_for_0 = 1.0 / counts[0]
#weight_for_1 = 1.0 / counts[1]

print(f"{weight_for_0: .6f}")
print(f"{weight_for_1: .4f}")
# Out:
#  0.500917
#  273.1966

# %% [markdown]
# Podemos ver que los pesos son practicamente una proporción de 500 a 1 aproximadamente

# %% [markdown]
# # Estandarizar los datos

# %%
mean = np.mean(train_features, axis=0)
train_features -= mean
val_features -= mean
std = np.std(train_features, axis=0)
train_features /= std
val_features /= std

# %% [markdown]
# # Modelo de clasificación binaria

# %%
from tensorflow import keras

model = keras.Sequential(
    [
        keras.layers.Dense(
            256, activation="relu", input_shape=(train_features.shape[-1],)
        ),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               7936
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 139,777
# Trainable params: 139,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Entrenar modelo tomando en cuenta pesos para los datos

# %%
metrics = [
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss="binary_crossentropy", metrics=metrics
)

callbacks = [keras.callbacks.ModelCheckpoint("fraud_model_at_epoch_{epoch}.h5")]
class_weight = {0: weight_for_0, 1: weight_for_1}

model.fit(
    train_features,
    train_targets,
    batch_size=2048,
    epochs=30,
    verbose=2,
    callbacks=callbacks,
    validation_data=(val_features, val_targets),
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 112/112 - 9s - loss: 0.4558 - fn: 47.0000 - fp: 14758.0000 - tn: 212671.0000 - tp: 370.0000 - precision: 0.0245 - recall: 0.8873 - val_loss: 0.0082 - val_fn: 14.0000 - val_fp: 101.0000 - val_tn: 56785.0000 - val_tp: 61.0000 - val_precision: 0.3765 - val_recall: 0.8133 - 9s/epoch - 79ms/step
# Epoch 2/30
# 112/112 - 6s - loss: 0.2185 - fn: 35.0000 - fp: 7861.0000 - tn: 219568.0000 - tp: 382.0000 - precision: 0.0463 - recall: 0.9161 - val_loss: 0.2399 - val_fn: 12.0000 - val_fp: 310.0000 - val_tn: 56576.0000 - val_tp: 63.0000 - val_precision: 0.1689 - val_recall: 0.8400 - 6s/epoch - 53ms/step
# Epoch 3/30
# 112/112 - 6s - loss: 0.2037 - fn: 30.0000 - fp: 8848.0000 - tn: 218581.0000 - tp: 387.0000 - precision: 0.0419 - recall: 0.9281 - val_loss: 0.0587 - val_fn: 12.0000 - val_fp: 153.0000 - val_tn: 56733.0000 - val_tp: 63.0000 - val_precision: 0.2917 - val_recall: 0.8400 - 6s/epoch - 53ms/step
# Epoch 4/30
# 112/112 - 6s - loss: 0.1762 - fn: 34.0000 - fp: 6600.0000 - tn: 220829.0000 - tp: 383.0000 - precision: 0.0548 - recall: 0.9185 - val_loss: 0.0442 - val_fn: 8.0000 - val_fp: 464.0000 - val_tn: 56422.0000 - val_tp: 67.0000 - val_precision: 0.1262 - val_recall: 0.8933 - 6s/epoch - 53ms/step
# Epoch 5/30
# 112/112 - 6s - loss: 0.5333 - fn: 40.0000 - fp: 9502.0000 - tn: 217927.0000 - tp: 377.0000 - precision: 0.0382 - recall: 0.9041 - val_loss: 0.1086 - val_fn: 7.0000 - val_fp: 1672.0000 - val_tn: 55214.0000 - val_tp: 68.0000 - val_precision: 0.0391 - val_recall: 0.9067 - 6s/epoch - 53ms/step
# Epoch 6/30
# 112/112 - 6s - loss: 1.0336 - fn: 44.0000 - fp: 20122.0000 - tn: 207307.0000 - tp: 373.0000 - precision: 0.0182 - recall: 0.8945 - val_loss: 0.0168 - val_fn: 17.0000 - val_fp: 17.0000 - val_tn: 56869.0000 - val_tp: 58.0000 - val_precision: 0.7733 - val_recall: 0.7733 - 6s/epoch - 53ms/step
# Epoch 7/30
# 112/112 - 6s - loss: 0.6035 - fn: 59.0000 - fp: 11023.0000 - tn: 216406.0000 - tp: 358.0000 - precision: 0.0315 - recall: 0.8585 - val_loss: 0.0206 - val_fn: 14.0000 - val_fp: 60.0000 - val_tn: 56826.0000 - val_tp: 61.0000 - val_precision: 0.5041 - val_recall: 0.8133 - 6s/epoch - 53ms/step
# Epoch 8/30
# 112/112 - 6s - loss: 0.4278 - fn: 59.0000 - fp: 11675.0000 - tn: 215754.0000 - tp: 358.0000 - precision: 0.0298 - recall: 0.8585 - val_loss: 0.1440 - val_fn: 9.0000 - val_fp: 776.0000 - val_tn: 56110.0000 - val_tp: 66.0000 - val_precision: 0.0784 - val_recall: 0.8800 - 6s/epoch - 54ms/step
# Epoch 9/30
# 112/112 - 6s - loss: 0.2039 - fn: 56.0000 - fp: 4974.0000 - tn: 222455.0000 - tp: 361.0000 - precision: 0.0677 - recall: 0.8657 - val_loss: 0.0377 - val_fn: 10.0000 - val_fp: 327.0000 - val_tn: 56559.0000 - val_tp: 65.0000 - val_precision: 0.1658 - val_recall: 0.8667 - 6s/epoch - 55ms/step
# Epoch 10/30
# 112/112 - 6s - loss: 0.4395 - fn: 42.0000 - fp: 9522.0000 - tn: 217907.0000 - tp: 375.0000 - precision: 0.0379 - recall: 0.8993 - val_loss: 0.3773 - val_fn: 8.0000 - val_fp: 10384.0000 - val_tn: 46502.0000 - val_tp: 67.0000 - val_precision: 0.0064 - val_recall: 0.8933 - 6s/epoch - 56ms/step
# Epoch 11/30
# 112/112 - 6s - loss: 0.4415 - fn: 49.0000 - fp: 6812.0000 - tn: 220617.0000 - tp: 368.0000 - precision: 0.0513 - recall: 0.8825 - val_loss: 0.0584 - val_fn: 13.0000 - val_fp: 97.0000 - val_tn: 56789.0000 - val_tp: 62.0000 - val_precision: 0.3899 - val_recall: 0.8267 - 6s/epoch - 54ms/step
# Epoch 12/30
# 112/112 - 6s - loss: 0.2806 - fn: 60.0000 - fp: 4630.0000 - tn: 222799.0000 - tp: 357.0000 - precision: 0.0716 - recall: 0.8561 - val_loss: 0.0397 - val_fn: 13.0000 - val_fp: 68.0000 - val_tn: 56818.0000 - val_tp: 62.0000 - val_precision: 0.4769 - val_recall: 0.8267 - 6s/epoch - 53ms/step
# Epoch 13/30
# 112/112 - 6s - loss: 0.2711 - fn: 61.0000 - fp: 4944.0000 - tn: 222485.0000 - tp: 356.0000 - precision: 0.0672 - recall: 0.8537 - val_loss: 0.0342 - val_fn: 12.0000 - val_fp: 150.0000 - val_tn: 56736.0000 - val_tp: 63.0000 - val_precision: 0.2958 - val_recall: 0.8400 - 6s/epoch - 54ms/step
# Epoch 14/30
# 112/112 - 6s - loss: 0.2193 - fn: 44.0000 - fp: 4026.0000 - tn: 223403.0000 - tp: 373.0000 - precision: 0.0848 - recall: 0.8945 - val_loss: 0.0325 - val_fn: 12.0000 - val_fp: 93.0000 - val_tn: 56793.0000 - val_tp: 63.0000 - val_precision: 0.4038 - val_recall: 0.8400 - 6s/epoch - 54ms/step
# Epoch 15/30
# 112/112 - 6s - loss: 0.2502 - fn: 46.0000 - fp: 5612.0000 - tn: 221817.0000 - tp: 371.0000 - precision: 0.0620 - recall: 0.8897 - val_loss: 0.1184 - val_fn: 11.0000 - val_fp: 1098.0000 - val_tn: 55788.0000 - val_tp: 64.0000 - val_precision: 0.0551 - val_recall: 0.8533 - 6s/epoch - 54ms/step
# Epoch 16/30
# 112/112 - 6s - loss: 0.1773 - fn: 49.0000 - fp: 6398.0000 - tn: 221031.0000 - tp: 368.0000 - precision: 0.0544 - recall: 0.8825 - val_loss: 0.0597 - val_fn: 11.0000 - val_fp: 390.0000 - val_tn: 56496.0000 - val_tp: 64.0000 - val_precision: 0.1410 - val_recall: 0.8533 - 6s/epoch - 53ms/step
# Epoch 17/30
# 112/112 - 6s - loss: 0.2177 - fn: 44.0000 - fp: 5941.0000 - tn: 221488.0000 - tp: 373.0000 - precision: 0.0591 - recall: 0.8945 - val_loss: 0.0854 - val_fn: 10.0000 - val_fp: 550.0000 - val_tn: 56336.0000 - val_tp: 65.0000 - val_precision: 0.1057 - val_recall: 0.8667 - 6s/epoch - 53ms/step
# Epoch 18/30
# 112/112 - 6s - loss: 0.2190 - fn: 35.0000 - fp: 8043.0000 - tn: 219386.0000 - tp: 382.0000 - precision: 0.0453 - recall: 0.9161 - val_loss: 0.0607 - val_fn: 10.0000 - val_fp: 454.0000 - val_tn: 56432.0000 - val_tp: 65.0000 - val_precision: 0.1252 - val_recall: 0.8667 - 6s/epoch - 54ms/step
# Epoch 19/30
# 112/112 - 6s - loss: 0.1590 - fn: 45.0000 - fp: 5564.0000 - tn: 221865.0000 - tp: 372.0000 - precision: 0.0627 - recall: 0.8921 - val_loss: 0.0597 - val_fn: 8.0000 - val_fp: 956.0000 - val_tn: 55930.0000 - val_tp: 67.0000 - val_precision: 0.0655 - val_recall: 0.8933 - 6s/epoch - 54ms/step
# Epoch 20/30
# 112/112 - 6s - loss: 1.6959 - fn: 45.0000 - fp: 11185.0000 - tn: 216244.0000 - tp: 372.0000 - precision: 0.0322 - recall: 0.8921 - val_loss: 0.0937 - val_fn: 12.0000 - val_fp: 113.0000 - val_tn: 56773.0000 - val_tp: 63.0000 - val_precision: 0.3580 - val_recall: 0.8400 - 6s/epoch - 54ms/step
# Epoch 21/30
# 112/112 - 6s - loss: 0.6785 - fn: 73.0000 - fp: 5215.0000 - tn: 222214.0000 - tp: 344.0000 - precision: 0.0619 - recall: 0.8249 - val_loss: 0.2089 - val_fn: 13.0000 - val_fp: 94.0000 - val_tn: 56792.0000 - val_tp: 62.0000 - val_precision: 0.3974 - val_recall: 0.8267 - 6s/epoch - 54ms/step
# Epoch 22/30
# 112/112 - 6s - loss: 0.2467 - fn: 85.0000 - fp: 2508.0000 - tn: 224921.0000 - tp: 332.0000 - precision: 0.1169 - recall: 0.7962 - val_loss: 0.1138 - val_fn: 15.0000 - val_fp: 41.0000 - val_tn: 56845.0000 - val_tp: 60.0000 - val_precision: 0.5941 - val_recall: 0.8000 - 6s/epoch - 53ms/step
# Epoch 23/30
# 112/112 - 6s - loss: 0.2439 - fn: 73.0000 - fp: 3272.0000 - tn: 224157.0000 - tp: 344.0000 - precision: 0.0951 - recall: 0.8249 - val_loss: 0.1078 - val_fn: 14.0000 - val_fp: 107.0000 - val_tn: 56779.0000 - val_tp: 61.0000 - val_precision: 0.3631 - val_recall: 0.8133 - 6s/epoch - 54ms/step
# Epoch 24/30
# 112/112 - 6s - loss: 0.2115 - fn: 90.0000 - fp: 2675.0000 - tn: 224754.0000 - tp: 327.0000 - precision: 0.1089 - recall: 0.7842 - val_loss: 0.0688 - val_fn: 13.0000 - val_fp: 135.0000 - val_tn: 56751.0000 - val_tp: 62.0000 - val_precision: 0.3147 - val_recall: 0.8267 - 6s/epoch - 54ms/step
# Epoch 25/30
# 112/112 - 6s - loss: 0.2212 - fn: 66.0000 - fp: 4235.0000 - tn: 223194.0000 - tp: 351.0000 - precision: 0.0765 - recall: 0.8417 - val_loss: 0.1492 - val_fn: 12.0000 - val_fp: 232.0000 - val_tn: 56654.0000 - val_tp: 63.0000 - val_precision: 0.2136 - val_recall: 0.8400 - 6s/epoch - 54ms/step
# Epoch 26/30
# 112/112 - 6s - loss: 0.4912 - fn: 87.0000 - fp: 1652.0000 - tn: 225777.0000 - tp: 330.0000 - precision: 0.1665 - recall: 0.7914 - val_loss: 0.1294 - val_fn: 18.0000 - val_fp: 5.0000 - val_tn: 56881.0000 - val_tp: 57.0000 - val_precision: 0.9194 - val_recall: 0.7600 - 6s/epoch - 53ms/step
# Epoch 27/30
# 112/112 - 6s - loss: 0.2558 - fn: 112.0000 - fp: 1200.0000 - tn: 226229.0000 - tp: 305.0000 - precision: 0.2027 - recall: 0.7314 - val_loss: 0.1208 - val_fn: 14.0000 - val_fp: 29.0000 - val_tn: 56857.0000 - val_tp: 61.0000 - val_precision: 0.6778 - val_recall: 0.8133 - 6s/epoch - 54ms/step
# Epoch 28/30
# 112/112 - 6s - loss: 0.2132 - fn: 58.0000 - fp: 2580.0000 - tn: 224849.0000 - tp: 359.0000 - precision: 0.1222 - recall: 0.8609 - val_loss: 0.1346 - val_fn: 14.0000 - val_fp: 31.0000 - val_tn: 56855.0000 - val_tp: 61.0000 - val_precision: 0.6630 - val_recall: 0.8133 - 6s/epoch - 53ms/step
# Epoch 29/30
# 112/112 - 6s - loss: 0.2114 - fn: 72.0000 - fp: 1777.0000 - tn: 225652.0000 - tp: 345.0000 - precision: 0.1626 - recall: 0.8273 - val_loss: 0.1130 - val_fn: 18.0000 - val_fp: 6.0000 - val_tn: 56880.0000 - val_tp: 57.0000 - val_precision: 0.9048 - val_recall: 0.7600 - 6s/epoch - 53ms/step
# Epoch 30/30
# 112/112 - 6s - loss: 0.2108 - fn: 100.0000 - fp: 177.0000 - tn: 227252.0000 - tp: 317.0000 - precision: 0.6417 - recall: 0.7602 - val_loss: 0.1775 - val_fn: 18.0000 - val_fp: 6.0000 - val_tn: 56880.0000 - val_tp: 57.0000 - val_precision: 0.9048 - val_recall: 0.7600 - 6s/epoch - 53ms/step

# %%
y_train_pred = model.predict(train_features)
y_train_pred[y_train_pred < 0.5] = 0
y_train_pred[y_train_pred >= 0.5] = 1

# %%
y_test_pred = model.predict(val_features)
y_test_pred[y_test_pred < 0.5] = 0
y_test_pred[y_test_pred >= 0.5] = 1

# %%
len(y_test_pred[:, 0])
# Out:
# 56961

# %%
y_test_pred[:, 0].sum()
# Out:
# 63.0

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
ConfusionMatrixDisplay.from_predictions(train_targets, y_train_pred, cmap=plt.cm.Greens)

# %%
# Recuperar "pesos" de los coeficientes en la epoca "X"
# CUIDADO AL CORRER ESTA CELDA

# model.load_weights("/content/fraud_model_at_epoch_1.h5")

# %%
ConfusionMatrixDisplay.from_predictions(val_targets, y_test_pred, cmap=plt.cm.Greens)

# %%
from sklearn.metrics import average_precision_score

# %%
y_test_prob = model.predict(val_features)

# %%
auprc = average_precision_score(val_targets, y_test_prob)
auprc
# Out:
# 0.6887338057784581

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(train_targets, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227429
#            1       0.75      0.82      0.78       417
#
#     accuracy                           1.00    227846
#    macro avg       0.88      0.91      0.89    227846
# weighted avg       1.00      1.00      1.00    227846

# %%
print(classification_report(val_targets, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56886
#            1       0.90      0.76      0.83        75
#
#     accuracy                           1.00     56961
#    macro avg       0.95      0.88      0.91     56961
# weighted avg       1.00      1.00      1.00     56961

# %% [markdown]
# # Ejercicios:
#
# * ¿Que sucedería con el modelo si no usamos el parámetro "class_weight"?
#
# * ¿Podemos recuperar solo la mejor época de nuestro entrenamiento?
#
# * ¿Porque la matriz de confusión no parece dar mucha luz sobre lo que ocurre?
